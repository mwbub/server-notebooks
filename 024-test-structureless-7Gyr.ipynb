# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import scipy.integrate as integrate
from astropy.table import Table
from galpy.util.multi import parallel_map
from galpy.df import quasiisothermaldf
from galpy.potential import MWPotential2014
from galpy.actionAngle import actionAngleStaeckel

# Set up QDF object
aA = actionAngleStaeckel(pot=MWPotential2014, c=True, delta=0.45)
qdf = quasiisothermaldf(1./3., 0.15, 0.075, 1., 1., pot=MWPotential2014, aA=aA, cutcounter=True)

# %%
def pz(z):
    result = integrate.quad(lambda R: qdf.density(R, z), 3/8., 13/8., epsabs=0.0001, epsrel=0.0001)
    print('Completed integration at z =', z)
    return result[0]

def pR(R):
    result = integrate.quad(lambda z: qdf.density(R, z), -0.25, 0.25, epsabs=0.0001, epsrel=0.0001)
    print('Completed integration at R =', R)
    return result[0]

def pvT(vT):
    result = integrate.dblquad(lambda z, R: qdf.pvT(vT, R, z), 3./8., 13./8., 
                               lambda R: -0.25, lambda R: 0.25, epsabs=0.0001, epsrel=0.0001)
    print("Completed integration at vT =", vT)
    return result[0]

R = np.linspace(3./8., 13./8., 100)
z = np.linspace(-0.25, 0.25, 100)
vT = np.linspace(0, 1.5, 100)
pRs = parallel_map(pR, R, numcores=50)
pzs = parallel_map(pz, z, numcores=50)
pvTs = parallel_map(pvT, vT, numcores=50)
# Out:
# Completed integration at R = 1.6123737373737375
# Completed integration at R = 1.5618686868686869
# Completed integration at R = 1.5871212121212122
# Completed integration at R = 1.5366161616161615
# Completed integration at R = 1.5113636363636362
# Completed integration at R = 1.4861111111111112
# Completed integration at R = 1.4608585858585859
# Completed integration at R = 1.4356060606060606
# Completed integration at R = 1.3345959595959596
# Completed integration at R = 1.4103535353535352
# Completed integration at R = 1.2335858585858586
# Completed integration at R = 1.2588383838383839
# Completed integration at R = 1.3851010101010102
# Completed integration at R = 1.0063131313131313
# Completed integration at R = 1.1578282828282829
# Completed integration at R = 1.2840909090909092
# Completed integration at R = 1.183080808080808
# Completed integration at R = 1.3093434343434343
# Completed integration at R = 1.3598484848484849
# Completed integration at R = 0.9558080808080808
# Completed integration at R = 0.9810606060606061
# Completed integration at R = 1.1073232323232323
# Completed integration at R = 1.0315656565656566
# Completed integration at R = 1.1325757575757576
# Completed integration at R = 1.2083333333333335
# Completed integration at R = 1.0568181818181817
# Completed integration at R = 0.8800505050505051
# Completed integration at R = 0.9305555555555556
# Completed integration at R = 1.0820707070707072
# Completed integration at R = 0.8295454545454546
# Completed integration at R = 0.9053030303030303
# Completed integration at R = 0.8042929292929293
# Completed integration at R = 0.8547979797979798
# Completed integration at R = 0.7285353535353536
# Completed integration at R = 0.779040404040404
# Completed integration at R = 0.7537878787878788
# Completed integration at R = 1.625
# Completed integration at R = 1.5744949494949494
# Completed integration at R = 1.5997474747474747
# Completed integration at R = 1.523989898989899
# Completed integration at R = 1.5492424242424243
# Completed integration at R = 1.4734848484848484
# Completed integration at R = 1.4987373737373737
# Completed integration at R = 1.4482323232323233
# Completed integration at R = 0.678030303030303
# Completed integration at R = 1.422979797979798
# Completed integration at R = 1.3472222222222223
# Completed integration at R = 1.3724747474747474
# Completed integration at R = 0.7032828282828283
# Completed integration at R = 1.246212121212121
# Completed integration at R = 1.2714646464646464
# Completed integration at R = 1.3977272727272727
# Completed integration at R = 0.6275252525252526
# Completed integration at R = 1.3219696969696968
# Completed integration at R = 0.6527777777777778
# Completed integration at R = 1.1704545454545454
# Completed integration at R = 0.9684343434343434
# Completed integration at R = 1.1957070707070707
# Completed integration at R = 1.220959595959596
# Completed integration at R = 1.2967171717171717
# Completed integration at R = 0.9936868686868687
# Completed integration at R = 1.1452020202020203
# Completed integration at R = 1.0441919191919191
# Completed integration at R = 1.018939393939394
# Completed integration at R = 1.1199494949494948
# Completed integration at R = 0.8926767676767676
# Completed integration at R = 1.0694444444444444
# Completed integration at R = 0.7916666666666667
# Completed integration at R = 0.9431818181818181
# Completed integration at R = 0.8674242424242424
# Completed integration at R = 1.0946969696969697
# Completed integration at R = 0.8421717171717171
# Completed integration at R = 0.9179292929292929
# Completed integration at R = 0.8169191919191919
# Completed integration at R = 0.7411616161616161
# Completed integration at R = 0.7664141414141414
# Completed integration at R = 0.6022727272727273
# Completed integration at R = 0.5265151515151515
# Completed integration at R = 0.5012626262626263
# Completed integration at R = 0.5517676767676768
# Completed integration at R = 0.577020202020202
# Completed integration at R = 0.7159090909090908
# Completed integration at R = 0.4255050505050505
# Completed integration at R = 0.476010101010101
# Completed integration at R = 0.45075757575757575
# Completed integration at R = 0.40025252525252525
# Completed integration at R = 0.375
# Completed integration at R = 0.6906565656565656
# Completed integration at R = 0.6654040404040404
# Completed integration at R = 0.6401515151515151
# Completed integration at R = 0.6148989898989898
# Completed integration at R = 0.5896464646464646
# Completed integration at R = 0.5138888888888888
# Completed integration at R = 0.5643939393939394
# Completed integration at R = 0.5391414141414141
# Completed integration at R = 0.48863636363636365
# Completed integration at R = 0.4633838383838384
# Completed integration at R = 0.43813131313131315
# Completed integration at R = 0.4128787878787879
# Completed integration at R = 0.38762626262626265
# Completed integration at z = -0.25
# Completed integration at z = -0.14898989898989898
# Completed integration at z = -0.20959595959595959
# Completed integration at z = 0.10353535353535359
# Completed integration at z = -0.2297979797979798
# Completed integration at z = -0.1893939393939394
# Completed integration at z = -0.17929292929292928
# Completed integration at z = -0.1994949494949495
# Completed integration at z = 0.09343434343434348
# Completed integration at z = -0.12878787878787878
# Completed integration at z = -0.1388888888888889
# Completed integration at z = -0.1590909090909091
# Completed integration at z = -0.2196969696969697
# Completed integration at z = 0.03282828282828287
# Completed integration at z = 0.05303030303030304
# Completed integration at z = -0.06818181818181818
# Completed integration at z = 0.1641414141414142
# Completed integration at z = 0.1540404040404041
# Completed integration at z = -0.07828282828282826
# Completed integration at z = -0.16919191919191917
# Completed integration at z = 0.13383838383838387
# Completed integration at z = -0.2398989898989899
# Completed integration at z = -0.058080808080808066
# Completed integration at z = 0.2146464646464647
# Completed integration at z = -0.10858585858585856
# Completed integration at z = 0.08333333333333337
# Completed integration at z = 0.06313131313131315
# Completed integration at z = 0.012626262626262652
# Completed integration at z = 0.14393939393939398
# Completed integration at z = 0.12373737373737376
# Completed integration at z = 0.19444444444444448
# Completed integration at z = -0.11868686868686867
# Completed integration at z = 0.2247474747474748
# Completed integration at z = 0.20454545454545459
# Completed integration at z = -0.09848484848484848
# Completed integration at z = 0.24494949494949497
# Completed integration at z = -0.007575757575757569
# Completed integration at z = 0.23484848484848486
# Completed integration at z = -0.027777777777777762
# Completed integration at z = -0.08838383838383837
# Completed integration at z = 0.07323232323232326
# Completed integration at z = 0.17424242424242425
# Completed integration at z = -0.03787878787878787
# Completed integration at z = 0.04292929292929293
# Completed integration at z = 0.0025252525252525415
# Completed integration at z = 0.11363636363636365
# Completed integration at z = -0.017676767676767652
# Completed integration at z = 0.18434343434343436
# Completed integration at z = 0.022727272727272763
# Completed integration at z = -0.047979797979797956
# Completed integration at z = -0.20454545454545453
# Completed integration at z = -0.24494949494949494
# Completed integration at z = -0.18434343434343434
# Completed integration at z = 0.10858585858585862
# Completed integration at z = 0.09848484848484851
# Completed integration at z = -0.17424242424242425
# Completed integration at z = 0.05808080808080812
# Completed integration at z = -0.21464646464646464
# Completed integration at z = -0.0732323232323232
# Completed integration at z = 0.22979797979797983
# Completed integration at z = -0.05303030303030301
# Completed integration at z = 0.0378787878787879
# Completed integration at z = 0.0883838383838384
# Completed integration at z = 0.16919191919191923
# Completed integration at z = -0.06313131313131312
# Completed integration at z = 0.21969696969696972
# Completed integration at z = 0.15909090909090912
# Completed integration at z = -0.22474747474747475
# Completed integration at z = 0.19949494949494956
# Completed integration at z = -0.14393939393939392
# Completed integration at z = 0.12878787878787884
# Completed integration at z = 0.17929292929292934
# Completed integration at z = -0.16414141414141414
# Completed integration at z = 0.06818181818181823
# Completed integration at z = 0.01767676767676768
# Completed integration at z = 0.2095959595959596
# Completed integration at z = -0.12373737373737373
# Completed integration at z = -0.0025252525252525138
# Completed integration at z = -0.1338383838383838
# Completed integration at z = 0.25
# Completed integration at z = -0.10353535353535354
# Completed integration at z = -0.19444444444444445
# Completed integration at z = -0.022727272727272707
# Completed integration at z = -0.15404040404040403
# Completed integration at z = -0.23484848484848486
# Completed integration at z = -0.012626262626262597
# Completed integration at z = 0.23989898989898994
# Completed integration at z = 0.1388888888888889
# Completed integration at z = 0.11868686868686873
# Completed integration at z = 0.148989898989899
# Completed integration at z = 0.0075757575757576245
# Completed integration at z = 0.07828282828282829
# Completed integration at z = 0.04797979797979801
# Completed integration at z = -0.08333333333333331
# Completed integration at z = -0.09343434343434343
# Completed integration at z = -0.0429292929292929
# Completed integration at z = -0.11363636363636362
# Completed integration at z = -0.03282828282828282
# Completed integration at z = 0.18939393939393945
# Completed integration at z = 0.02777777777777779
# /home/mwbub/repos/galpy/galpy/df/quasiisothermaldf.py:269: RuntimeWarning: divide by zero encountered in log
#   -kappa*jr*numpy.exp(-2.*lnsr)
#
# Completed integration at vT = 0.0
# Completed integration at vT = 1.4848484848484849
# Completed integration at vT = 1.3636363636363638
# Completed integration at vT = 1.0303030303030303
# Completed integration at vT = 1.0
# Completed integration at vT = 0.12121212121212122
# Completed integration at vT = 1.4242424242424243
# Completed integration at vT = 0.15151515151515152
# Completed integration at vT = 1.0606060606060606
# Completed integration at vT = 0.9090909090909092
# Completed integration at vT = 0.9696969696969697
# Completed integration at vT = 0.696969696969697
# Completed integration at vT = 0.9393939393939394
# Completed integration at vT = 1.2424242424242424
# Completed integration at vT = 1.3333333333333335
# Completed integration at vT = 0.8181818181818182
# Completed integration at vT = 0.7878787878787878
# Completed integration at vT = 0.8484848484848485
# Completed integration at vT = 0.8787878787878788
# Completed integration at vT = 0.7575757575757576
# Completed integration at vT = 1.303030303030303
# Completed integration at vT = 1.0909090909090908
# Completed integration at vT = 0.09090909090909091
# Completed integration at vT = 1.1515151515151516
# Completed integration at vT = 1.2727272727272727
# Completed integration at vT = 1.2121212121212122
# Completed integration at vT = 1.1212121212121213
# Completed integration at vT = 0.7272727272727273
# Completed integration at vT = 1.1818181818181819
# Completed integration at vT = 0.06060606060606061
# Completed integration at vT = 0.6666666666666667
# Completed integration at vT = 0.6363636363636364
# Completed integration at vT = 0.030303030303030304
# Completed integration at vT = 0.6060606060606061
# Completed integration at vT = 0.18181818181818182
# Completed integration at vT = 0.3939393939393939
# Completed integration at vT = 0.24242424242424243
# Completed integration at vT = 0.36363636363636365
# Completed integration at vT = 0.21212121212121213
# Completed integration at vT = 0.42424242424242425
# Completed integration at vT = 0.5757575757575758
# Completed integration at vT = 0.30303030303030304
# Completed integration at vT = 0.5151515151515151
# Completed integration at vT = 0.2727272727272727
# Completed integration at vT = 0.33333333333333337
# Completed integration at vT = 0.4545454545454546
# Completed integration at vT = 0.5454545454545454
# Completed integration at vT = 0.48484848484848486
# Completed integration at vT = 1.5
# Completed integration at vT = 1.4393939393939394
# Completed integration at vT = 1.378787878787879
# Completed integration at vT = 1.0151515151515151
# Completed integration at vT = 0.13636363636363635
# Completed integration at vT = 1.0454545454545454
# Completed integration at vT = 0.9242424242424243
# Completed integration at vT = 0.9848484848484849
# Completed integration at vT = 1.0757575757575757
# Completed integration at vT = 0.16666666666666669
# Completed integration at vT = 0.7727272727272727
# Completed integration at vT = 0.8030303030303031
# Completed integration at vT = 0.8333333333333334
# Completed integration at vT = 1.3484848484848486
# Completed integration at vT = 0.7121212121212122
# Completed integration at vT = 0.9545454545454546
# Completed integration at vT = 1.2575757575757576
# Completed integration at vT = 0.8636363636363636
# Completed integration at vT = 0.10606060606060606
# Completed integration at vT = 1.3181818181818181
# Completed integration at vT = 0.8939393939393939
# Completed integration at vT = 1.1060606060606062
# Completed integration at vT = 1.2878787878787878
# Completed integration at vT = 0.7424242424242424
# Completed integration at vT = 1.1363636363636365
# Completed integration at vT = 1.196969696969697
# Completed integration at vT = 0.07575757575757576
# Completed integration at vT = 1.1666666666666667
# Completed integration at vT = 0.6818181818181819
# Completed integration at vT = 1.2272727272727273
# Completed integration at vT = 0.045454545454545456
# Completed integration at vT = 0.6515151515151515
# Completed integration at vT = 0.6212121212121212
# Completed integration at vT = 0.25757575757575757
# Completed integration at vT = 0.19696969696969696
# Completed integration at vT = 0.5909090909090909
# Completed integration at vT = 0.3787878787878788
# Completed integration at vT = 0.2272727272727273
# Completed integration at vT = 0.4090909090909091
# Completed integration at vT = 0.3484848484848485
# Completed integration at vT = 0.4393939393939394
# Completed integration at vT = 1.4545454545454546
# Completed integration at vT = 0.2878787878787879
# Completed integration at vT = 0.3181818181818182
# Completed integration at vT = 0.5606060606060607
# Completed integration at vT = 0.5303030303030303
# Completed integration at vT = 0.4696969696969697
# Completed integration at vT = 0.5
# Completed integration at vT = 1.393939393939394
# Completed integration at vT = 1.4090909090909092
# Completed integration at vT = 0.015151515151515152
# Completed integration at vT = 1.4696969696969697

# %%
filename = os.path.expandvars('$SCRATCH/data/structureless/03-new-7Gyr/new-7Gyr_0.fits')
data = Table.read(filename, format='fits')
data = data[(data['R'] > 3/8.) & (data['R'] < 13/8.)]

filename2 = os.path.expandvars('$SCRATCH/data/qdf_samples/100000000_samples.fits')
data2 = Table.read(filename2, format='fits')

# %%
plt.figure(figsize=(10,8))
plt.hist(data['vR'], normed=True, histtype='step', bins='auto', label='$vR$')
plt.hist(data['vz'], normed=True, histtype='step', bins='auto', label='$vz$')
plt.hist(data['vT'], normed=True, histtype='step', bins='auto', label='$vT$')
plt.hist(data2['vR'], normed=True, histtype='step', bins='auto', label='Original $vR$')
plt.hist(data2['vz'], normed=True, histtype='step', bins='auto', label='Original $vz$')
plt.hist(data2['vT'], normed=True, histtype='step', bins='auto', label='Original $vT$')
plt.xlabel('$v/v_0$')
plt.ylabel('$P(v)$')
plt.xlim([-2, 2])
plt.legend()
plt.show()

fig, ax = plt.subplots(1, 2, figsize=(16,6))
ax[0].plot(R, pRs/(np.sum(pRs) * (R[1] - R[0])))
ax[0].hist(data['R'], normed=True, histtype='step', bins='auto')
ax[0].set_xlabel('$R/R_0$')
ax[0].set_ylabel('$P(R)$')
ax[1].plot(z, pzs/(np.sum(pzs) * (z[1] - z[0])))
ax[1].hist(data['z'], normed=True, histtype='step', bins='auto')
ax[1].set_xlabel('$z/R_0$')
ax[1].set_ylabel('$P(z)$')
ax[1].set_xlim(-0.25, 0.25)
plt.show()

plt.figure(figsize=(10,8))
plt.plot(vT, pvTs/(np.sum(pvTs) * (vT[1] - vT[0])))
plt.hist(data['vT'], normed=True, histtype='step', bins='auto', label='$vT$')
plt.xlabel('$v_T/v_0$')
plt.ylabel('$P(v_T)$')
plt.show()

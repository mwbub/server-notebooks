# %%
import os
import sys

sys.path.append(os.path.expandvars('$SCRATCH/code/plots'))
from plots import animate_disk, animate_RvT

# %%
basename = os.path.expandvars('$SCRATCH/data/transient_spirals/06-single-cycle/single-cycle')

# %%
animate_disk(basename, numframes=101)
# Out:
# /usr/local/lib/python3.6/site-packages/astropy/table/column.py:929: RuntimeWarning: invalid value encountered in less
#   return getattr(self.data, oper)(other)
# <video width="720" height="720" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
animate_RvT(basename, numframes=101)
# Out:
# /usr/local/lib/python3.6/site-packages/astropy/table/column.py:929: RuntimeWarning: invalid value encountered in greater
#   return getattr(self.data, oper)(other)
#
# /usr/local/lib/python3.6/site-packages/astropy/table/column.py:929: RuntimeWarning: invalid value encountered in less
#   return getattr(self.data, oper)(other)
# <video width="720" height="720" controls autoplay loop>
#   <source type="video/mp4" src="...
